# %%
import pandas as pd
import numpy as np
import os
import matplotlib
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams, figure
rcParams['figure.figsize'] = 15,9
# figure(num=None, figsize=(15, 9), dpi=80, facecolor='w', edgecolor='k')
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA

# %% [markdown]
# # Time Series on Week Basis

# %%
file1 = 'US Coffee C Futures Historical Data.csv'
table1 = pd.read_csv(file1)
table1
# Out:
#               Date   Price    Open    High     Low    Vol. Change %
# 0     Aug 02, 2000   86.45   86.80   87.50   86.00   2.63K    0.17%
# 1     Aug 01, 2000   86.30   86.50   87.75   86.10   2.74K   -0.17%
# 2     Jul 31, 2000   86.45   85.75   87.00   84.10   3.99K   -1.09%
# 3     Jul 28, 2000   87.40   86.75   88.10   86.75   2.48K    1.51%
# 4     Jul 27, 2000   86.10   86.60   88.75   86.00   3.89K   -0.98%
# 5     Jul 26, 2000   86.95   85.00   87.50   85.00   3.20K    2.05%
# 6     Jul 25, 2000   85.20   85.50   87.25   85.00   4.75K   -1.27%
# 7     Jul 24, 2000   86.30   87.00   89.00   84.40  10.79K  -10.71%
# 8     Jul 21, 2000   96.65   99.50  103.25   96.25   7.27K   -1.13%
# 9     Jul 20, 2000   97.75  100.00  104.00   95.35  10.47K  -12.06%
# 10    Jul 19, 2000  111.15  113.00  113.00  112.25   0.06K   -4.59%
# 11    Jul 18, 2000  116.50  118.00  119.00  113.00   0.09K   18.09%
# 12    Jul 17, 2000   98.65   97.50   98.50   98.50   0.06K   10.66%
# 13    Jul 14, 2000   89.15   92.00   95.50   89.40   0.05K  -10.13%
# 14    Jul 13, 2000   99.20   93.00   99.50   93.00   0.02K   10.59%
# 15    Jul 12, 2000   89.70   90.50   90.50   88.80   0.01K   -0.44%
# 16    Jul 11, 2000   90.10   83.00   91.15   84.50   0.04K    7.26%
# 17    Jul 10, 2000   84.00   83.50   85.50   83.50   0.05K    3.96%
# 18    Jul 07, 2000   80.80   82.25   82.75   79.75   0.17K   -2.47%
# 19    Jul 06, 2000   82.85   84.60   85.50   83.00   0.26K   -2.99%
# 20    Jul 05, 2000   85.40   84.75   85.90   85.00   0.12K    0.65%
# 21    Jun 30, 2000   84.85   86.90   87.00   84.60   0.18K   -1.79%
# 22    Jun 29, 2000   86.40   87.25   87.65   86.30   0.15K   -1.43%
# 23    Jun 28, 2000   87.65   88.50   89.25   87.30   0.28K   -0.96%
# 24    Jun 27, 2000   88.50   86.00   88.50   86.00   0.37K    1.55%
# 25    Jun 26, 2000   87.15   86.50   87.40   86.00   0.18K    0.11%
# 26    Jun 23, 2000   87.05   86.75   89.50   86.75   1.15K    1.04%
# 27    Jun 22, 2000   86.15   85.25   86.75   85.25   1.69K    2.01%
# 28    Jun 21, 2000   84.45   86.70   87.70   84.00   9.82K   -3.21%
# 29    Jun 20, 2000   87.25   86.75   88.00   86.75   6.17K    0.06%
# ...            ...     ...     ...     ...     ...     ...      ...
# 4970  Oct 07, 1980  128.38  128.38  128.60  124.05   1.39K    3.22%
# 4971  Oct 06, 1980  124.37  127.06  127.50  124.20   0.90K   -3.00%
# 4972  Oct 03, 1980  128.22  131.65  132.80  127.25   1.39K    1.03%
# 28    Aug 17, 2000   78.55   78.30   79.15   77.40   4.94K    0.32%
# 29    Aug 16, 2000   78.30   75.60   78.50   75.60   5.05K   -0.38%
# 30    Aug 15, 2000   78.60   78.35   79.10   77.75   3.72K   -0.25%
# 31    Aug 14, 2000   78.80   79.75   80.00   76.50   6.72K   -2.29%
# 32    Aug 11, 2000   80.65   79.60   81.00   79.60   3.63K    1.32%
# 33    Aug 10, 2000   79.60   79.50   81.20   78.45   5.81K    0.13%
# 34    Aug 09, 2000   79.50   82.90   83.50   79.30   8.56K   -5.02%
# 35    Aug 08, 2000   83.70   85.50   86.00   83.40   4.50K   -1.99%
# 36    Aug 07, 2000   85.40   85.50   86.00   84.80   2.53K   -0.23%
# 37    Aug 04, 2000   85.60   85.85   86.25   85.00   2.52K   -0.29%
# 38    Aug 03, 2000   85.85   86.50   87.50   85.00   2.66K   -0.69%
#
# [9859 rows x 7 columns]

# %%
df['Date']=df['Date'].astype(str)
df['Date']=pd.to_datetime(df['Date'])
df = df.set_index(['Date'])
df
# Out:
#              Price    Open    High     Low    Vol. Change %
# Date
# 2000-08-02   86.45   86.80   87.50   86.00   2.63K    0.17%
# 2000-08-01   86.30   86.50   87.75   86.10   2.74K   -0.17%
# 2000-07-31   86.45   85.75   87.00   84.10   3.99K   -1.09%
# 2000-07-28   87.40   86.75   88.10   86.75   2.48K    1.51%
# 2000-07-27   86.10   86.60   88.75   86.00   3.89K   -0.98%
# 2000-07-26   86.95   85.00   87.50   85.00   3.20K    2.05%
# 2000-07-25   85.20   85.50   87.25   85.00   4.75K   -1.27%
# 2000-07-24   86.30   87.00   89.00   84.40  10.79K  -10.71%
# 2000-07-21   96.65   99.50  103.25   96.25   7.27K   -1.13%
# 2000-07-20   97.75  100.00  104.00   95.35  10.47K  -12.06%
# 2000-07-19  111.15  113.00  113.00  112.25   0.06K   -4.59%
# 2000-07-18  116.50  118.00  119.00  113.00   0.09K   18.09%
# 2000-07-17   98.65   97.50   98.50   98.50   0.06K   10.66%
# 2000-07-14   89.15   92.00   95.50   89.40   0.05K  -10.13%
# 2000-07-13   99.20   93.00   99.50   93.00   0.02K   10.59%
# 2000-07-12   89.70   90.50   90.50   88.80   0.01K   -0.44%
# 2000-07-11   90.10   83.00   91.15   84.50   0.04K    7.26%
# 2000-07-10   84.00   83.50   85.50   83.50   0.05K    3.96%
# 2000-07-07   80.80   82.25   82.75   79.75   0.17K   -2.47%
# 2000-07-06   82.85   84.60   85.50   83.00   0.26K   -2.99%
# 2000-07-05   85.40   84.75   85.90   85.00   0.12K    0.65%
# 2000-06-30   84.85   86.90   87.00   84.60   0.18K   -1.79%
# 2000-06-29   86.40   87.25   87.65   86.30   0.15K   -1.43%
# 2000-06-28   87.65   88.50   89.25   87.30   0.28K   -0.96%
# 2000-06-27   88.50   86.00   88.50   86.00   0.37K    1.55%
# 2000-06-26   87.15   86.50   87.40   86.00   0.18K    0.11%
# 2000-06-23   87.05   86.75   89.50   86.75   1.15K    1.04%
# 2000-06-22   86.15   85.25   86.75   85.25   1.69K    2.01%
# 2000-06-21   84.45   86.70   87.70   84.00   9.82K   -3.21%
# 2000-06-20   87.25   86.75   88.00   86.75   6.17K    0.06%
# ...            ...     ...     ...     ...     ...      ...
# 2000-09-14   77.20   79.00   78.00   76.50   0.01K   -2.95%
# 2000-09-13   79.55   77.00   80.00   79.00   0.04K    1.14%
# 2000-09-12   78.65   78.50   78.50   78.00   0.02K    1.16%
# 2000-09-11   77.75   76.75   78.00   76.50   0.02K    0.45%
# 2000-09-08   77.40   78.00   78.00   76.60   0.04K   -0.77%
# 2000-09-07   78.00   75.50   78.00   76.50   0.07K    3.65%
# 2000-09-06   75.25   73.10   75.25   74.50   0.05K    2.94%
# 2000-09-05   73.10   74.00   73.70   72.20   0.31K   -2.53%
# 2000-09-01   75.00   75.50   77.00   75.00   0.11K    0.67%
# 2000-08-31   74.50   73.50   75.20   73.50   0.13K    0.81%
# 2000-08-30   73.90   74.00   74.75   73.60   0.19K   -1.07%
# 2000-08-29   74.70   75.25   75.70   74.40   0.33K   -0.66%
# 2000-08-28   75.20   78.00   78.00   74.50   0.28K   -3.28%
# 2000-08-25   77.75   78.00   78.25   77.40   0.35K   -0.06%
# 2000-08-24   77.80   75.00   78.50   75.00   0.71K    4.29%
# 2000-08-23   74.60   76.75   77.40   74.50   2.31K   -3.24%
# 2000-08-22   77.10   76.25   77.80   76.25   6.55K   -0.52%
# 2000-08-21   77.50   77.25   78.50   77.10   5.70K   -1.15%
# 2000-08-18   78.40   78.75   78.90   77.50   3.28K   -0.19%
# 2000-08-17   78.55   78.30   79.15   77.40   4.94K    0.32%
# 2000-08-16   78.30   75.60   78.50   75.60   5.05K   -0.38%
# 2000-08-15   78.60   78.35   79.10   77.75   3.72K   -0.25%
# 2000-08-14   78.80   79.75   80.00   76.50   6.72K   -2.29%
# 2000-08-11   80.65   79.60   81.00   79.60   3.63K    1.32%
# 2000-08-10   79.60   79.50   81.20   78.45   5.81K    0.13%
# 2000-08-09   79.50   82.90   83.50   79.30   8.56K   -5.02%
# 2000-08-08   83.70   85.50   86.00   83.40   4.50K   -1.99%
# 2000-08-07   85.40   85.50   86.00   84.80   2.53K   -0.23%
# 2000-08-04   85.60   85.85   86.25   85.00   2.52K   -0.29%
# 2000-08-03   85.85   86.50   87.50   85.00   2.66K   -0.69%
#
# [9859 rows x 6 columns]

# %%
df.sort_index(inplace=True)
df
# Out:
#              Price    Open    High     Low    Vol. Change %
# Date
# 1980-08-26  130.75  130.62  132.00  124.50   0.29K    2.28%
# 1980-08-27  131.08  131.50  132.00  127.50   0.33K    0.25%
# 1980-08-28  130.22  128.12  130.50  127.25   0.16K   -0.66%
# 1980-08-29  128.00  126.25  128.90  125.50   0.08K   -1.70%
# 1980-09-02  125.57  124.62  125.75  123.10   0.14K   -1.90%
# 1980-09-03  127.25  124.37  127.49  124.00   0.37K    1.34%
# 1980-09-04  127.00  126.67  127.10  125.50   0.08K   -0.20%
# 1980-09-05  128.00  128.00  128.00  126.25   0.11K    0.79%
# 1980-09-08  134.39  126.55  135.00  126.55   0.11K    4.99%
# 1980-09-09  136.35  130.75  136.75  130.75   0.12K    1.46%
# 2019-09-20   98.40   98.50   99.75   98.05  22.02K    0.05%
# 2019-09-23   99.00   98.50  100.90   98.15  17.16K    0.61%
# 2019-09-24   99.15   98.85  100.35   98.45  13.62K    0.15%
# 2019-09-25  100.95   98.90  101.55   97.25  24.94K    1.82%
# 2019-09-26  101.78  101.18  102.90  100.63       -    0.82%
#
# [9859 rows x 6 columns]

# %%
df = df.asfreq('D')
df
# Out:
#              Price    Open    High     Low    Vol. Change %
# Date
# 1980-08-26  130.75  130.62  132.00  124.50   0.29K    2.28%
# 1980-08-27  131.08  131.50  132.00  127.50   0.33K    0.25%
# 1980-08-28  130.22  128.12  130.50  127.25   0.16K   -0.66%
# 1980-08-29  128.00  126.25  128.90  125.50   0.08K   -1.70%
# 1980-08-30     NaN     NaN     NaN     NaN     NaN      NaN
# 1980-08-31     NaN     NaN     NaN     NaN     NaN      NaN
# 1980-09-01     NaN     NaN     NaN     NaN     NaN      NaN
# 1980-09-02  125.57  124.62  125.75  123.10   0.14K   -1.90%
# 1980-09-03  127.25  124.37  127.49  124.00   0.37K    1.34%
# 1980-09-04  127.00  126.67  127.10  125.50   0.08K   -0.20%
# 1980-09-05  128.00  128.00  128.00  126.25   0.11K    0.79%
# 1980-09-06     NaN     NaN     NaN     NaN     NaN      NaN
# 1980-09-07     NaN     NaN     NaN     NaN     NaN      NaN
# 1980-09-08  134.39  126.55  135.00  126.55   0.11K    4.99%
# 1980-09-09  136.35  130.75  136.75  130.75   0.12K    1.46%
# 1980-09-10  135.63  135.05  138.25  135.05   0.17K   -0.53%
# 1980-09-11  130.38  132.55  133.00  130.00   0.02K   -3.87%
# 1980-09-12  126.00  127.49  128.00  126.00   0.02K   -3.36%
# 1980-09-13     NaN     NaN     NaN     NaN     NaN      NaN
# 1980-09-14     NaN     NaN     NaN     NaN     NaN      NaN
# 1980-09-15  122.24  123.90  124.50  119.00   0.09K   -2.98%
# 1980-09-16  128.87  122.49  130.00  121.50   0.18K    5.42%
# 1980-09-17  128.08  126.97  128.50  124.50   0.18K   -0.61%
# 1980-09-18  127.90  125.87  128.00  125.50   0.14K   -0.14%
# 1980-09-19  125.00  126.45  127.00  124.00   0.06K   -2.27%
# 1980-09-20     NaN     NaN     NaN     NaN     NaN      NaN
# 1980-09-21     NaN     NaN     NaN     NaN     NaN      NaN
# 1980-09-22  135.19  130.25  135.50  130.00   1.43K    8.15%
# 1980-09-23  131.36  132.87  134.75  131.25   1.18K   -2.83%
# 1980-09-24  129.82  130.25  132.25  129.50   1.17K   -1.17%
# ...            ...     ...     ...     ...     ...      ...
# 2019-08-28   94.20   93.00   93.90   92.85   0.01K    0.43%
# 2019-08-29   91.90   93.35   93.35   93.35   0.01K   -2.44%
# 2019-08-30   93.60   93.30   93.30   93.30   0.01K    1.85%
# 2019-08-31     NaN     NaN     NaN     NaN     NaN      NaN
# 2019-09-01     NaN     NaN     NaN     NaN     NaN      NaN
# 2019-09-02     NaN     NaN     NaN     NaN     NaN      NaN
# 2019-09-03   95.58   95.23   96.60   94.23       -    2.12%
# 2019-09-04   96.62   95.80   96.95   95.53       -    1.09%
# 2019-09-05   95.08   96.88   97.45   95.08       -   -1.59%
# 2019-09-06   96.80   95.18   97.35   95.03       -    1.81%
# 2019-09-07     NaN     NaN     NaN     NaN     NaN      NaN
# 2019-09-08     NaN     NaN     NaN     NaN     NaN      NaN
# 2019-09-09   98.80   96.88   99.20   95.38       -    2.07%
# 2019-09-10  101.78   98.68  102.25   98.03       -    3.02%
# 2019-09-11  100.15  101.15  101.15  101.15   0.00K   -1.60%
# 2019-09-12  103.48  102.68  103.85  101.18       -    3.33%
# 2019-09-13  102.48  103.23  103.60  102.08       -   -0.97%
# 2019-09-14     NaN     NaN     NaN     NaN     NaN      NaN
# 2019-09-15     NaN     NaN     NaN     NaN     NaN      NaN
# 2019-09-16  103.83  102.00  104.90  101.68       -    1.32%
# 2019-09-17  100.60  103.60  104.05   99.98       -   -3.11%
# 2019-09-18  100.68  100.83  101.83  100.13       -    0.08%
# 2019-09-19   98.35  100.35  100.75   98.10  17.60K   -2.31%
# 2019-09-20   98.40   98.50   99.75   98.05  22.02K    0.05%
# 2019-09-21     NaN     NaN     NaN     NaN     NaN      NaN
# 2019-09-22     NaN     NaN     NaN     NaN     NaN      NaN
# 2019-09-23   99.00   98.50  100.90   98.15  17.16K    0.61%
# 2019-09-24   99.15   98.85  100.35   98.45  13.62K    0.15%
# 2019-09-25  100.95   98.90  101.55   97.25  24.94K    1.82%
# 2019-09-26  101.78  101.18  102.90  100.63       -    0.82%
#
# [14276 rows x 6 columns]

# %%
df=df.resample('D').interpolate()[::7]
df
# Out:
#               Price    Open    High     Low    Vol. Change %
# Date
# 1980-08-26  130.750  130.62  132.00  124.50   0.29K    2.28%
# 1980-09-02  125.570  124.62  125.75  123.10   0.14K   -1.90%
# 1980-09-09  136.350  130.75  136.75  130.75   0.12K    1.46%
# 1980-09-16  128.870  122.49  130.00  121.50   0.18K    5.42%
# 1980-09-23  131.360  132.87  134.75  131.25   1.18K   -2.83%
# 1980-09-30  126.660  129.25  131.65  126.10   1.12K   -1.62%
# 1980-10-07  128.380  128.38  128.60  124.05   1.39K    3.22%
# 1980-10-14  132.110  132.37  132.75  131.00   0.57K   -0.12%
# 1980-10-21  126.990  128.75  129.00  126.75   0.63K   -2.17%
# 1980-10-28  126.070  128.62  128.75  126.00   0.43K   -2.26%
# 1980-11-04  122.165  122.81  123.80  120.85     NaN      NaN
# 1980-11-11  108.300  107.62  109.50  107.50   0.43K    0.25%
# 1980-11-18  110.000  102.55  110.90  102.10   1.38K    5.69%
# 1980-11-25  113.930  112.10  113.98  110.50   0.21K    0.38%
# 1980-12-02  114.380  115.50  115.50  113.75   0.11K   -1.18%
# 1980-12-09  115.750  116.37  116.75  114.75   0.08K   -0.39%
# 1980-12-16  117.000  115.50  117.00  115.00   0.03K    2.68%
# 1980-12-23  126.060  125.00  126.99  124.50   1.54K    2.07%
# 1980-12-30  127.000  128.57  128.90  126.70   0.84K   -1.92%
# 1981-01-06  131.510  132.80  133.85  131.10   1.04K   -0.14%
# 1981-01-13  133.590  132.12  134.50  132.00   0.96K    1.47%
# 1981-01-20  130.370  129.35  130.50  127.50   0.85K    0.83%
# 1981-01-27  120.620  121.70  122.40  119.50   1.15K    0.33%
# 1981-02-03  119.690  121.25  121.90  119.60   0.43K   -1.87%
# 1981-02-10  121.000  121.50  122.25  120.80   0.25K    0.24%
# 1981-02-17  120.180  122.62  122.95  119.50   0.43K   -2.49%
# 1981-02-24  122.430  121.60  122.50  121.60   0.15K    0.56%
# 1981-03-03  121.750  121.25  122.25  120.50   0.14K    0.17%
# 1981-03-10  118.630  119.37  119.99  119.00   0.06K   -0.42%
# 1981-03-17  118.500  121.00  121.00  118.50   0.03K   -0.88%
# ...             ...     ...     ...     ...     ...      ...
# 2019-03-05   96.450   96.45   96.45   96.45       -    2.50%
# 2019-03-12   92.800   94.55   94.55   94.50   0.01K   -4.62%
# 2019-03-19   96.600   97.03   97.80   96.50       -   -0.26%
# 2019-03-26   95.350   94.35   95.85   93.95  25.12K    1.17%
# 2019-04-02   91.650   92.35   92.55   91.25  22.45K   -0.49%
# 2019-04-09   93.650   93.30   94.85   93.15  47.97K    0.75%
# 2019-04-16   90.500   91.05   91.55   89.80  19.19K   -0.98%
# 2019-04-23   91.500   92.00   92.00   90.10   0.18K    0.44%
# 2019-04-30   91.850   91.35   93.85   91.35   0.13K    0.55%
# 2019-05-07   86.650   87.65   87.65   87.00   0.03K   -3.99%
# 2019-05-14   90.680   90.08   92.60   90.00       -    0.72%
# 2019-05-21   92.900   89.60   93.35   88.50  32.02K    5.27%
# 2019-05-28   96.050   93.20   96.45   92.65  36.41K    2.95%
# 2019-06-04  105.650  103.25  106.15  102.70  43.49K    1.83%
# 2019-06-11   97.000   98.10  100.45   96.85  39.47K   -1.62%
# 2019-06-18   94.300   95.85   96.00   94.00   9.77K   -1.82%
# 2019-06-25  106.450  103.00  105.35  103.00   0.09K    4.36%
# 2019-07-02  108.250  110.35  110.35  108.60   0.09K   -1.72%
# 2019-07-09  108.000  106.43  108.30  105.35       -    3.10%
# 2019-07-16  106.030  110.18  110.18  105.45       -   -3.59%
# 2019-07-23  102.300  105.15  105.60  102.15  26.11K   -2.66%
# 2019-07-30   99.500  101.05  101.15   98.80  19.26K   -1.63%
# 2019-08-06   97.050   95.75   97.75   95.20  26.45K    1.46%
# 2019-08-13   96.350   93.70   96.60   93.15  30.65K    2.77%
# 2019-08-20   91.450   91.35   91.80   89.60  12.09K    0.33%
# 2019-08-27   93.800   93.85   93.85   93.40   0.01K   -0.37%
# 2019-09-03   95.580   95.23   96.60   94.23       -    2.12%
# 2019-09-10  101.780   98.68  102.25   98.03       -    3.02%
# 2019-09-17  100.600  103.60  104.05   99.98       -   -3.11%
# 2019-09-24   99.150   98.85  100.35   98.45  13.62K    0.15%
#
# [2040 rows x 6 columns]

# %%
# Select only price

df = df.loc[:,['Price']]

# %%
# Plot graph first

# plot graph

plt.xlabel("Date")
plt.ylabel("Price")
plt.plot(df)
# Out:
# /home/erolerten/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
# Determining roling statistics
rolmean = df.rolling(window=52).mean()
rolstd = df.rolling(window=52).std()
print(rolmean,rolstd)
# Out:
#                  Price
# Date
# 1980-08-26         NaN
# 1980-09-02         NaN
# 1980-09-09         NaN
# 1980-09-16         NaN
# 1980-09-23         NaN
# 1980-09-30         NaN
# 1980-10-07         NaN
# 1980-10-14         NaN
# 1980-10-21         NaN
# 1980-10-28         NaN
# 1980-11-04         NaN
# 1980-11-11         NaN
# 1980-11-18         NaN
# 1980-11-25         NaN
# 1980-12-02         NaN
# 1980-12-09         NaN
# 1980-12-16         NaN
# 1980-12-23         NaN
# 1980-12-30         NaN
# 1981-01-06         NaN
# 1981-01-13         NaN
# 1981-01-20         NaN
# 1981-01-27         NaN
# 1981-02-03         NaN
# 1981-02-10         NaN
# 1981-02-17         NaN
# 1981-02-24         NaN
# 1981-03-03         NaN
# 1981-03-10         NaN
# 1981-03-17         NaN
# ...                ...
# 2019-03-05  108.492788
# 2019-03-12  107.961058
# 2019-03-19  107.531250
# 2019-03-26  107.077404
# 2019-04-02  106.597596
# 2019-04-09  106.137019
# 2019-04-16  105.693750
# 2019-04-23  105.174519
# 2019-04-30  104.583173
# 2019-05-07  104.008173
# 2019-05-14  103.580865
# 2019-05-21  103.043365
# 2019-05-28  102.577981
# 2019-06-04  102.312596
# 2019-06-11  101.921250
# 2019-06-18  101.540481
# 2019-06-25  101.379904
# 2019-07-02  101.377981
# 2019-07-09  101.302019
# 2019-07-16  101.308365
# 2019-07-23  101.142019
# 2019-07-30  100.942019
# 2019-08-06  100.711250
# 2019-08-13  100.543942
# 2019-08-20  100.418942
# 2019-08-27  100.314135
# 2019-09-03  100.272404
# 2019-09-10  100.379712
# 2019-09-17  100.545096
# 2019-09-24  100.584519
#
# [2040 rows x 1 columns]                Price
# Date
# 1980-08-26       NaN
# 1980-09-02       NaN
# 1980-09-09       NaN
# 1980-09-16       NaN
# 1980-09-23       NaN
# 1980-09-30       NaN
# 1980-10-07       NaN
# 1980-10-14       NaN
# 1980-10-21       NaN
# 1980-10-28       NaN
# 1980-11-04       NaN
# 1980-11-11       NaN
# 1980-11-18       NaN
# 1980-11-25       NaN
# 1980-12-02       NaN
# 1980-12-09       NaN
# 1980-12-16       NaN
# 1980-12-23       NaN
# 1980-12-30       NaN
# 1981-01-06       NaN
# 1981-01-13       NaN
# 1981-01-20       NaN
# 1981-01-27       NaN
# 1981-02-03       NaN
# 1981-02-10       NaN
# 1981-02-17       NaN
# 1981-02-24       NaN
# 1981-03-03       NaN
# 1981-03-10       NaN
# 1981-03-17       NaN
# ...              ...
# 2019-03-05  8.682375
# 2019-03-12  8.781835
# 2019-03-19  8.780395
# 2019-03-26  8.788525
# 2019-04-02  8.938242
# 2019-04-09  8.977157
# 2019-04-16  9.170930
# 2019-04-23  9.195957
# 2019-04-30  9.040821
# 2019-05-07  9.213970
# 2019-05-14  9.308272
# 2019-05-21  9.096083
# 2019-05-28  8.813150
# 2019-06-04  8.497245
# 2019-06-11  8.256308
# 2019-06-18  8.139375
# 2019-06-25  7.952886
# 2019-07-02  7.951179
# 2019-07-09  7.866618
# 2019-07-16  7.870367
# 2019-07-23  7.753127
# 2019-07-30  7.656311
# 2019-08-06  7.587675
# 2019-08-13  7.586047
# 2019-08-20  7.682565
# 2019-08-27  7.735816
# 2019-09-03  7.755746
# 2019-09-10  7.736875
# 2019-09-17  7.645616
# 2019-09-24  7.632779
#
# [2040 rows x 1 columns]

# %%
# Plot rolling statistics

orig = plt.plot(df, color='blue',label='Original')
mean = plt.plot(rolmean, color='red',label='Rolling Mean')
std = plt.plot(rolstd, color='yellow',label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviaion')
plt.show(block=False)

# %%
# Perform Dickey-Fuller test:

print("Result of Dickey-Fuller Test:")
dftest=adfuller(df['Price'],autolag='AIC')

dfoutput = pd.Series(dftest[0:4], index=['Test Statistics','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critial Value (%s)'%key]=value
    
print(dfoutput)
# Out:
# Result of Dickey-Fuller Test:
# Test Statistics                  -3.227519
# p-value                           0.018446
# #Lags Used                       22.000000
# Number of Observations Used    2017.000000
# Critial Value (1%)               -3.433596
# Critial Value (5%)               -2.862974
# Critial Value (10%)              -2.567533
# dtype: float64

# %%
rolmean.dropna(inplace=True)
rolstd.dropna(inplace=True)

# %%
def test_stationary(timeseries):
    
    # Determining rolling stats
    movingAverage = timeseries.rolling(window=52).mean()
    movingStd = timeseries.rolling(window=52).std()
    
    # Plot rolling stats
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(movingAverage, color='red',label='Rolling Mean')
    std = plt.plot(movingStd, color='yellow',label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviaion')
    plt.show(block=False)
    
    # Perform Dickey-Fuller test:

    print("Result of Dickey-Fuller Test:")
    dftest=adfuller(timeseries['Price'],autolag='AIC')

    dfoutput = pd.Series(dftest[0:4], index=['Test Statistics','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critial Value (%s)'%key]=value

    print(dfoutput)

# %%
test_stationary(df)
# Out:
# Result of Dickey-Fuller Test:
# Test Statistics                  -3.227519
# p-value                           0.018446
# #Lags Used                       22.000000
# Number of Observations Used    2017.000000
# Critial Value (1%)               -3.433596
# Critial Value (5%)               -2.862974
# Critial Value (10%)              -2.567533
# dtype: float64

# %%
exponentialDecayWeightedAverage = df.ewm(halflife=52, min_periods=0,adjust=True).mean()
plt.plot(df)
plt.plot(exponentialDecayWeightedAverage,color='red')

# %%
df_minus_movingExponentialDecayAverage = df - exponentialDecayWeightedAverage
test_stationary(df_minus_movingExponentialDecayAverage)
# Out:
# Result of Dickey-Fuller Test:
# Test Statistics                  -4.566655
# p-value                           0.000149
# #Lags Used                       22.000000
# Number of Observations Used    2017.000000
# Critial Value (1%)               -3.433596
# Critial Value (5%)               -2.862974
# Critial Value (10%)              -2.567533
# dtype: float64

# %%
df_shifted = df - df.shift()
plt.plot(df_shifted)

# %%
df_shifted.dropna(inplace=True)
test_stationary(df_shifted)
# Out:
# Result of Dickey-Fuller Test:
# Test Statistics               -9.350699e+00
# p-value                        8.311098e-16
# #Lags Used                     2.600000e+01
# Number of Observations Used    2.012000e+03
# Critial Value (1%)            -3.433604e+00
# Critial Value (5%)            -2.862978e+00
# Critial Value (10%)           -2.567535e+00
# dtype: float64

# %%
decomposition = seasonal_decompose(df,freq=30)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(df_shifted, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal, label='Seasonal')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residual')
plt.legend(loc='best')

decomposedLogData = residual
decomposedLogData.dropna(inplace=True)
test_stationary(residual)
# Out:
# Result of Dickey-Fuller Test:
# Test Statistics               -1.410322e+01
# p-value                        2.596516e-26
# #Lags Used                     1.900000e+01
# Number of Observations Used    1.990000e+03
# Critial Value (1%)            -3.433640e+00
# Critial Value (5%)            -2.862993e+00
# Critial Value (10%)           -2.567544e+00
# dtype: float64

# %%
# ACF and PACF plots
lag_acf = acf(df_shifted, nlags=20)
lag_pacf = pacf(df_shifted,nlags=20)

# Plot ACF
plt.subplot(121)
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(df_shifted)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(df_shifted)),linestyle='--',color='gray')
plt.title('Autocorrelation function')

# Plot PACF
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(df_shifted)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(df_shifted)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation function')
plt.tight_layout()
# Out:
# /home/erolerten/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)

# %%
# df_shifted = df_shifted.asfreq('D')

# %%
# AR Model
model = ARIMA(df_shifted,order=(2,1,0))
results_AR = model.fit(disp=-1)
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)
plt.plot(df_shifted)
plt.plot(results_AR.fittedvalues,color='red')
plt.title('RSS: %.4f'% sum((results_AR.fittedvalues-df_shifted['Price'])**2))
print("Plotting AR-Model")
# Out:
# Plotting AR-Model

# %%
# MA Model

model = ARIMA(df_shifted, order=(0, 1, 1))  
results_MA = model.fit(disp=-1)  
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)
plt.plot(df_shifted)
plt.plot(results_MA.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_MA.fittedvalues-df_shifted['Price'])**2))
print("Plotting MA-Model")
# Out:
# Plotting MA-Model

# %%
model = ARIMA(df_shifted, order=(2, 1, 1))  
results_ARIMA = model.fit(disp=-1)  
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)
plt.plot(df_shifted)
plt.plot(results_ARIMA.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_ARIMA.fittedvalues-df_shifted['Price'])**2))
print("Plotting ARIMA-Model")
# Out:
# Plotting ARIMA-Model

# %% [markdown]
# ## TODO: The part below must be reviewed!!

# %% [markdown]
# check out this link
# https://www.analyticsvidhya.com/blog/2016/02/time-series-forecasting-codes-python/
# and find an analogy for comparing predi

# %%
predictions_AR_diff = pd.Series(results_AR.fittedvalues, copy=True)
print(predictions_AR_diff.head())
# Out:
# Date
# 1980-09-09   -0.000066
# 1980-09-16   -8.305309
# 1980-09-23    7.572398
# 1980-09-30   -1.282586
# 1980-10-07    1.880382
# Freq: 7D, dtype: float64

# %%
predictions_AR_diff_cumsum = predictions_AR_diff.cumsum()
print (predictions_AR_diff_cumsum.head())
# Out:
# Date
# 1980-09-09   -0.000066
# 1980-09-16   -8.305375
# 1980-09-23   -0.732977
# 1980-09-30   -2.015564
# 1980-10-07   -0.135181
# Freq: 7D, dtype: float64

# %%
predictions_AR_df = pd.Series(df_shifted.iloc[0],index=df_shifted.index)
predictions_AR_df = predictions_AR_df.add(predictions_AR_diff_cumsum,fill_value=0)
predictions_AR_df.head()
# Out:
# Date
# 1980-09-02         NaN
# 1980-09-09   -0.000066
# 1980-09-16   -8.305375
# 1980-09-23   -0.732977
# 1980-09-30   -2.015564
# Freq: 7D, dtype: float64

# %%
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)
plt.plot(df_shifted)
plt.plot(predictions_AR_df)
